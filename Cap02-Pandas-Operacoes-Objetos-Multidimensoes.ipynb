# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import xarray

# %%
df = pd.Series([1,2,3,4,5],['luiz','luiz','luiz','luiz','luiz'])

# %%
df
# Out:
# luiz    1
# luiz    2
# luiz    3
# luiz    4
# luiz    5
# dtype: int64

# %%
dicionario = {"Nome":['Luiz','Jennifer'],"Idade":[28,23]}

# %%
df2 = pd.DataFrame(dicionario)

# %%
df2
# Out:
#        Nome  Idade
# 0      Luiz     28
# 1  Jennifer     23

# %%
data = np.random.randint(1,10,(5,3,2))

# %%
df2.to_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:  (index: 2)
# Coordinates:
#   * index    (index) int64 0 1
# Data variables:
#     Nome     (index) object 'Luiz' 'Jennifer'
#     Idade    (index) int64 28 23

# %%
data
# Out:
# array([[[9, 4],
#         [1, 5],
#         [1, 2]],
#
#        [[4, 2],
#         [4, 9],
#         [4, 1]],
#
#        [[6, 5],
#         [2, 9],
#         [3, 9]],
#
#        [[1, 9],
#         [4, 3],
#         [5, 5]],
#
#        [[1, 4],
#         [6, 8],
#         [4, 9]]])

# %%
data = data.reshape(5,6).T

# %%
data
# Out:
# array([[9, 4, 6, 1, 1],
#        [4, 2, 5, 9, 4],
#        [1, 4, 2, 4, 6],
#        [5, 9, 9, 3, 8],
#        [1, 4, 3, 5, 4],
#        [2, 1, 9, 5, 9]])

# %%
df3 = pd.DataFrame(
    data = data,
    index = pd.MultiIndex.from_product([[2015,2016,2017],['BRL','USA']]),
    columns = ['item {}'.format(i) for i in range(1,6)]
)

# %%
df3
# Out:
#           item 1  item 2  item 3  item 4  item 5
# 2015 BRL       9       4       6       1       1
#      USA       4       2       5       9       4
# 2016 BRL       1       4       2       4       6
#      USA       5       9       9       3       8
# 2017 BRL       1       4       3       5       4
#      USA       2       1       9       5       9

# %%
usdata = pd.DataFrame(
    np.array([[500000,1000000],
    [600000,2000000],
    [700000,3000000]]),
    columns = ['População','PIB'],
    index = [2018,2020,2021]
)

# %%
usdata
# Out:
#       População      PIB
# 2018     500000  1000000
# 2020     600000  2000000
# 2021     700000  3000000

# %%
chinadata =  pd.DataFrame(
    np.array([[10000000,4000000],
    [20000000,50000000],
    [30000000,60000000]]),
    columns = ['População','PIB'],
    index = [2018,2020,2021]
)

# %%
chinadata
# Out:
#       População       PIB
# 2018   10000000   4000000
# 2020   20000000  50000000
# 2021   30000000  60000000

# %%
USChina = {'US':usdata,'China':chinadata}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SAMSUN~1\AppData\Local\Temp/ipykernel_10680/253201612.py in <module>
# ----> 1 USChina.to_xarray()
#
# AttributeError: 'dict' object has no attribute 'to_xarray'
